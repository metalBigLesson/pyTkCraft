# %%
import random
from typing import List
from enum import Enum


class Tool_Type(Enum):
    SWORD = 1
    PICKAXE = 2
    SHOVEL = 3
    AXE = 4
    HOE = 5

class Block_Data():
    right_tool: Tool_Type
    color: str
    slide: float
    solidity: float

    def __init__(self, right_tool, color, slide=0, solidity=1):
        self.right_tool = right_tool
        self.color = color
        self.slide = slide
        self.solidity = solidity


class Grass(Block_Data):
    def __init__(self):
        super.__init__(Tool_Type.SHOVEL, 'green')

class Gravel(Block_Data):
    def __init__(self):
        super.__init__(Tool_Type.SHOVEL, 'lightgrey')

class Sand(Block_Data):
    def __init__(self):
        super.__init__(Tool_Type.SHOVEL, 'wheat')

class Mud(Block_Data):
    def __init__(self):
        super.__init__(Tool_Type.SHOVEL, 'ivoryblack')

class Mycelium(Block_Data):
    def __init__(self):
        super.__init__(Tool_Type.SHOVEL, 'plum4')

class Stone(Block_Data):
    def __init__(self):
        super.__init__(Tool_Type.PICKAXE, 'grey')



class Block_Sate():

    def __init__(self, depth):

    def decided_by_biome(self, h_min, h_max, hot):


class


class Chunk:
    def __init__(self, h1, h2):
        incline_sign = 1

class Game:
    def __init__(self):
        self.map: List[Chunk] = []
